# %% [markdown]
# Just another method for keyword search, in our case vector search. You don't need to dig deep into it now.
# Only knowing that it exists and that we combine both these methods to get a more reliable search result it sufficient.
